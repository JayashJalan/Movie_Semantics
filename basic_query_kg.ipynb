# %%
import os
from dotenv import  load_dotenv
load_dotenv()
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")

# %%
from langchain_neo4j import Neo4jGraph
graph = Neo4jGraph(url=NEO4J_URI,username=NEO4J_USERNAME,password=NEO4J_PASSWORD,refresh_schema=False)
graph
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from langchain_neo4j import Neo4jGraph
#       2 graph = Neo4jGraph(url=NEO4J_URI,username=NEO4J_USERNAME,password=NEO4J_PASSWORD,refresh_schema=False)
#       3 graph
#
# ModuleNotFoundError: No module named 'langchain_neo4j'

# %%
# !pip install langchain_neo4j
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain_neo4j
#   Using cached langchain_neo4j-0.5.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: langchain<0.4.0,>=0.3.7 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain_neo4j) (0.3.27)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.39 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain_neo4j) (0.3.79)
# Collecting neo4j<6.0.0,>=5.25.0 (from langchain_neo4j)
#   Downloading neo4j-5.28.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting neo4j-graphrag<2.0.0,>=1.9.0 (from langchain_neo4j)
#   Downloading neo4j_graphrag-1.11.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.4.37)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (2.12.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (2.0.44)
# Requirement already satisfied: requests<3,>=2 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (6.0.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain<0.4.0,>=0.3.7->langchain_neo4j) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain_neo4j) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain_neo4j) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain_neo4j) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.39->langchain_neo4j) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4.0,>=0.3.39->langchain_neo4j) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.25.0)
# Requirement already satisfied: anyio in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (4.11.0)
# Requirement already satisfied: certifi in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (1.0.9)
# Requirement already satisfied: idna in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.16.0)
# Requirement already satisfied: pytz in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from neo4j<6.0.0,>=5.25.0->langchain_neo4j) (2025.2)
# Collecting fsspec<2025.0.0,>=2024.9.0 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting json-repair<0.45.0,>=0.44.1 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j)
#   Downloading json_repair-0.44.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy<3.0.0,>=2.0.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j) (2.0.2)
# Requirement already satisfied: pypdf<7.0.0,>=6.0.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j) (6.1.3)
# Collecting scipy<2.0.0,>=1.13.0 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j)
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (60 kB)
# Collecting types-pyyaml<7.0.0.0,>=6.0.12.20240917 (from neo4j-graphrag<2.0.0,>=1.9.0->langchain_neo4j)
#   Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain_neo4j) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain_neo4j) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain_neo4j) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain_neo4j) (2.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain<0.4.0,>=0.3.7->langchain_neo4j) (1.3.1)
# Downloading langchain_neo4j-0.5.0-py3-none-any.whl (31 kB)
# Downloading neo4j-5.28.3-py3-none-any.whl (313 kB)
# Downloading neo4j_graphrag-1.11.0-py3-none-any.whl (206 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Downloading json_repair-0.44.1-py3-none-any.whl (22 kB)
# Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.3/30.3 MB 10.3 MB/s  0:00:02m0:00:0100:01
# Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl (20 kB)
# Installing collected packages: types-pyyaml, scipy, neo4j, json-repair, fsspec, neo4j-graphrag, langchain_neo4j
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [langchain_neo4j] [fsspec]
# Successfully installed fsspec-2024.12.0 json-repair-0.44.1 langchain_neo4j-0.5.0 neo4j-5.28.3 neo4j-graphrag-1.11.0 scipy-1.13.1 types-pyyaml-6.0.12.20250915

# %%
from langchain_neo4j import Neo4jGraph
graph = Neo4jGraph(url=NEO4J_URI,username=NEO4J_USERNAME,password=NEO4J_PASSWORD,refresh_schema=False)
graph
# Out:
# /Users/jayashjalan/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 from langchain_neo4j import Neo4jGraph
# ----> 2 graph = Neo4jGraph(url=NEO4J_URI,username=NEO4J_USERNAME,password=NEO4J_PASSWORD,refresh_schema=False)
#       3 graph
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_neo4j/graphs/neo4j_graph.py:122, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     107 def __init__(
#     108     self,
#     109     url: Optional[str] = None,
#    (...)
#     118     enhanced_schema: bool = False,
#     119 ) -> None:
#     120     """Create a new Neo4j graph wrapper instance."""
# --> 122     url = get_from_dict_or_env({"url": url}, "url", "NEO4J_URI")
#     123     # if username and password are "", assume Neo4j auth is disabled
#     124     if username == "" and password == "":
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/utils/env.py:56, in get_from_dict_or_env(data, key, env_key, default)
#      52     return data[key]
#      54 key_for_err = key[0] if isinstance(key, (list, tuple)) else key
# ---> 56 return get_from_env(key_for_err, env_key, default=default)
#
# File ~/Library/Python/3.9/lib/python/site-packages/langchain_core/utils/env.py:85, in get_from_env(key, env_key, default)
#      79     return default
#      80 msg = (
#      81     f"Did not find {key}, please add an environment variable"
#      82     f" `{env_key}` which contains it, or pass"
#      83     f" `{key}` as a named parameter."
#      84 )
# ---> 85 raise ValueError(msg)
#
# ValueError: Did not find url, please add an environment variable `NEO4J_URI` which contains it, or pass `url` as a named parameter.
